# %%
from IPython.display import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
import json

with open('data/train.json') as fp:
    train = json.load(fp)
labels = train['annotations'][:100000]

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')
# Out:
# /home/ubuntu/anaconda2/envs/fashion/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
i = 9

# %%
i +=1
image_path = f'images/{i}.jpg'
print(tuple(filter(lambda x: x['imageId'] == str(i), labels))[0])
img = image.load_img(image_path, target_size=(224, 224))

x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
preds = model.predict(x)

print('Predicted:', decode_predictions(preds)[0])
Image(image_path)
# Out:
# {'labelId': ['91', '66', '59', '49', '151', '105', '225'], 'imageId': '10'}
# Predicted: [('n04479046', 'trench_coat', 0.44208747), ('n03594734', 'jean', 0.13413574), ('n03404251', 'fur_coat', 0.06828388), ('n03047690', 'clog', 0.050907664), ('n03770439', 'miniskirt', 0.039284144)]

# %%
sum(item[2] for item in decode_predictions(preds)[0])
# Out:
# 0.9085027566179633

# %% [markdown]
# # lol let's search bikinis

# %%
bikinis = []
start = 1
for i in range(start, start + 1000):
    if i/50 == i//50:
        print(i)
    image_path = f'images/{i}.jpg'
    img = image.load_img(image_path, target_size=(224, 224))

    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = model.predict(x)
    if decode_predictions(preds)[0][0][1] == 'bikini':
        bikinis.append(i)
        print(f'{i}: bikini')
# Out:
# 12: bikini
# 27: bikini
# 50
# 66: bikini
# 100
# 140: bikini
# 143: bikini
# 150
# 187: bikini
# 200
# 212: bikini
# 250
# 255: bikini
# 294: bikini
# 297: bikini
# 300
# 342: bikini
# 350
# 360: bikini
# 387: bikini
# 400
# 408: bikini
# 415: bikini
# 440: bikini
# 450
# 460: bikini
# 472: bikini
# 500
# 501: bikini
# 502: bikini
# 514: bikini
# 525: bikini
# 539: bikini
# 550
# 568: bikini
# 596: bikini
# 600
# 640: bikini
# 650
# 688: bikini
# 700
# 703: bikini
# 750
# 757: bikini
# 797: bikini
# 800
# 850
# 850: bikini
# 861: bikini
# 884: bikini
# 900
# 914: bikini
# 945: bikini
# 948: bikini
# 950
# 955: bikini
# 961: bikini
# 986: bikini
# 1000

# %%
i = 0

# %%
ii = f'images/{bikinis[i]}.jpg' 
i += 1
Image(ii)
